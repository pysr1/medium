# %% [markdown]
# <a href="https://colab.research.google.com/github/pysr1/medium/blob/master/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Packages and Data:

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
from nltk.corpus import stopwords 
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import string
nltk.download('stopwords')


medium = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2018/2018-12-04/medium_datasci.csv'
medium_df = pd.read_csv(medium).drop('x1', 1)    
medium_df = medium_df[~medium_df['title'].isna()]
medium_df['subtitle'] = medium_df['subtitle'].fillna("")
medium_df['publication'] = medium_df['publication'].fillna("")
medium_df['text'] = medium_df['title'] + " " + medium_df['subtitle'] + " " + medium_df['publication']
medium_df['words'] = medium_df['text'].str.strip().str.split('[\W_]+')
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Look at First Few Rows:

# %%
medium_df.head()
# Out:
#                                                title  ...                                              words
# 0               Online Animation: Mixamo vs Norah AI  ...  [Online, Animation, Mixamo, vs, Norah, AI, Onl...
# 1                                             A.I. ?  ...                                           [A, I, ]
# 2                        Futures of AI, Friendly AI?  ...  [Futures, of, AI, Friendly, AI, From, Physics,...
# 3     The Value Generated through AI led Mindfulness  ...  [The, Value, Generated, through, AI, led, Mind...
# 4  Os Melhores Links de JulhoCmeras Vintage, Goog...  ...  [Os, Melhores, Links, de, JulhoCmeras, Vintage...
#
# [5 rows x 22 columns]

# %%
nltk.download('vader_lexicon')

def get_sentiment(string):

  sentiment = SentimentIntensityAnalyzer()
  scores = sentiment.polarity_scores(string)
  compound = scores['compound']
  return compound

medium_df['Sentiment Score'] = [get_sentiment(line) for line in medium_df['text']]
medium_df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#                                                title  ... Sentiment Score
# 0               Online Animation: Mixamo vs Norah AI  ...          0.0000
# 1                                             A.I. ?  ...          0.0000
# 2                        Futures of AI, Friendly AI?  ...          0.4939
# 3     The Value Generated through AI led Mindfulness  ...          0.6369
# 4  Os Melhores Links de JulhoCmeras Vintage, Goog...  ...         -0.5574
#
# [5 rows x 23 columns]

# %% [markdown]
# Seems to be working:

# %%
medium_df[['title','subtitle','Sentiment Score']].sort_values('Sentiment Score').head(10)
# Out:
#                                                    title  ... Sentiment Score
# 76379         Detecting Breast Cancer with Deep Learning  ...         -0.9816
# 18613  Investigating the Effects of Terrorism on Econ...  ...         -0.9729
# 28453              School Bullying and Deep Surveillance  ...         -0.9694
# 6685              Olden and Modern Civilisation Problems  ...         -0.9682
# 60067          How to Recover from a Social Media Crisis  ...         -0.9643
# 41950                 AI and Suicide Risk Identification  ...         -0.9612
# 20494  The Evil Dead Is A Sad Metaphor For Data Scien...  ...         -0.9602
# 34566             Recall and Precision in Skewed Classes  ...         -0.9590
# 69025     How Dead Neurons Hurt Deep Learning Training ?  ...         -0.9580
# 18483             Analyzing patterns in Global Terrorism  ...         -0.9571
#
# [10 rows x 3 columns]
